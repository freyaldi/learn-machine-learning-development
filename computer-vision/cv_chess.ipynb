# %% [markdown]
# <a href="https://colab.research.google.com/github/freyaldi/learn-machine-learning-development/blob/main/computer-vision/cv_chess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-07-10 09:03:03--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-07-10 09:03:03--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   365MB/s    in 0.2s
#
# 2023-07-10 09:03:04 (365 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Bishop', 'Pawn', 'Knight', 'Queen', 'King', 'Rook']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 46s - loss: 1.8563 - accuracy: 0.1764 - val_loss: 1.7867 - val_accuracy: 0.1731 - 46s/epoch - 736ms/step
# Epoch 2/50
# 63/63 - 43s - loss: 1.7830 - accuracy: 0.2184 - val_loss: 1.7786 - val_accuracy: 0.2115 - 43s/epoch - 678ms/step
# Epoch 3/50
# 63/63 - 46s - loss: 1.7786 - accuracy: 0.2104 - val_loss: 1.7452 - val_accuracy: 0.2308 - 46s/epoch - 730ms/step
# Epoch 4/50
# 63/63 - 42s - loss: 1.7498 - accuracy: 0.2305 - val_loss: 1.7287 - val_accuracy: 0.2308 - 42s/epoch - 667ms/step
# Epoch 5/50
# 63/63 - 42s - loss: 1.6835 - accuracy: 0.3066 - val_loss: 1.7514 - val_accuracy: 0.1923 - 42s/epoch - 672ms/step
# Epoch 6/50
# 63/63 - 42s - loss: 1.6655 - accuracy: 0.2766 - val_loss: 1.6430 - val_accuracy: 0.3077 - 42s/epoch - 660ms/step
# Epoch 7/50
# 63/63 - 42s - loss: 1.5647 - accuracy: 0.3627 - val_loss: 1.5913 - val_accuracy: 0.3462 - 42s/epoch - 663ms/step
# Epoch 8/50
# 63/63 - 44s - loss: 1.5711 - accuracy: 0.3527 - val_loss: 1.5960 - val_accuracy: 0.3269 - 44s/epoch - 702ms/step
# Epoch 9/50
# 63/63 - 42s - loss: 1.4886 - accuracy: 0.3808 - val_loss: 1.6662 - val_accuracy: 0.3269 - 42s/epoch - 660ms/step
# Epoch 10/50
# 63/63 - 42s - loss: 1.4113 - accuracy: 0.4208 - val_loss: 1.5884 - val_accuracy: 0.3654 - 42s/epoch - 662ms/step
# Epoch 11/50
# 63/63 - 42s - loss: 1.3801 - accuracy: 0.4709 - val_loss: 1.4973 - val_accuracy: 0.3654 - 42s/epoch - 663ms/step
# Epoch 12/50
# 63/63 - 41s - loss: 1.3102 - accuracy: 0.4790 - val_loss: 1.6019 - val_accuracy: 0.3269 - 41s/epoch - 648ms/step
# Epoch 13/50
# 63/63 - 41s - loss: 1.3008 - accuracy: 0.4970 - val_loss: 1.7612 - val_accuracy: 0.3654 - 41s/epoch - 656ms/step
# Epoch 14/50
# 63/63 - 42s - loss: 1.2532 - accuracy: 0.5090 - val_loss: 1.5105 - val_accuracy: 0.4423 - 42s/epoch - 664ms/step
# Epoch 15/50
# 63/63 - 42s - loss: 1.2267 - accuracy: 0.5070 - val_loss: 1.4547 - val_accuracy: 0.3654 - 42s/epoch - 661ms/step
# Epoch 16/50
# 63/63 - 42s - loss: 1.1514 - accuracy: 0.5671 - val_loss: 1.5177 - val_accuracy: 0.3654 - 42s/epoch - 664ms/step
# Epoch 17/50
# 63/63 - 42s - loss: 1.1204 - accuracy: 0.5631 - val_loss: 1.6615 - val_accuracy: 0.3654 - 42s/epoch - 673ms/step
# Epoch 18/50
# 63/63 - 41s - loss: 1.0849 - accuracy: 0.5752 - val_loss: 1.4112 - val_accuracy: 0.3846 - 41s/epoch - 653ms/step
# Epoch 19/50
# 63/63 - 41s - loss: 1.0974 - accuracy: 0.5872 - val_loss: 1.4577 - val_accuracy: 0.4808 - 41s/epoch - 649ms/step
# Epoch 20/50
# 63/63 - 42s - loss: 1.0510 - accuracy: 0.6052 - val_loss: 1.5761 - val_accuracy: 0.3654 - 42s/epoch - 661ms/step
# Epoch 21/50
# 63/63 - 42s - loss: 0.9872 - accuracy: 0.6453 - val_loss: 1.4314 - val_accuracy: 0.4038 - 42s/epoch - 660ms/step
# Epoch 22/50
# 63/63 - 41s - loss: 0.9544 - accuracy: 0.6593 - val_loss: 1.6443 - val_accuracy: 0.3077 - 41s/epoch - 649ms/step
# Epoch 23/50
# 63/63 - 42s - loss: 0.8599 - accuracy: 0.6914 - val_loss: 1.5216 - val_accuracy: 0.4808 - 42s/epoch - 669ms/step
# Epoch 24/50
# 63/63 - 41s - loss: 0.8723 - accuracy: 0.6814 - val_loss: 1.3533 - val_accuracy: 0.5000 - 41s/epoch - 658ms/step
# Epoch 25/50
# 63/63 - 42s - loss: 0.8185 - accuracy: 0.6894 - val_loss: 1.6545 - val_accuracy: 0.3654 - 42s/epoch - 663ms/step
# Epoch 26/50
# 63/63 - 41s - loss: 0.7654 - accuracy: 0.7214 - val_loss: 1.4211 - val_accuracy: 0.5385 - 41s/epoch - 648ms/step
# Epoch 27/50
# 63/63 - 41s - loss: 0.7176 - accuracy: 0.7315 - val_loss: 1.7907 - val_accuracy: 0.3462 - 41s/epoch - 653ms/step
# Epoch 28/50
# 63/63 - 42s - loss: 0.8256 - accuracy: 0.7114 - val_loss: 1.4178 - val_accuracy: 0.4808 - 42s/epoch - 671ms/step
# Epoch 29/50
# 63/63 - 44s - loss: 0.7102 - accuracy: 0.7535 - val_loss: 1.5254 - val_accuracy: 0.4423 - 44s/epoch - 705ms/step
# Epoch 30/50
# 63/63 - 42s - loss: 0.7360 - accuracy: 0.7194 - val_loss: 1.2721 - val_accuracy: 0.5577 - 42s/epoch - 668ms/step
# Epoch 31/50
# 63/63 - 43s - loss: 0.6450 - accuracy: 0.7715 - val_loss: 1.7147 - val_accuracy: 0.4615 - 43s/epoch - 683ms/step
# Epoch 32/50
# 63/63 - 46s - loss: 0.6125 - accuracy: 0.7856 - val_loss: 1.8018 - val_accuracy: 0.3846 - 46s/epoch - 733ms/step
# Epoch 33/50
# 63/63 - 43s - loss: 0.6289 - accuracy: 0.7675 - val_loss: 1.4682 - val_accuracy: 0.5192 - 43s/epoch - 686ms/step
# Epoch 34/50
# 63/63 - 44s - loss: 0.5820 - accuracy: 0.7796 - val_loss: 1.9075 - val_accuracy: 0.3654 - 44s/epoch - 699ms/step
# Epoch 35/50
# 63/63 - 42s - loss: 0.5581 - accuracy: 0.7856 - val_loss: 2.1185 - val_accuracy: 0.3462 - 42s/epoch - 667ms/step
# Epoch 36/50
# 63/63 - 42s - loss: 0.5644 - accuracy: 0.7916 - val_loss: 1.5672 - val_accuracy: 0.5192 - 42s/epoch - 664ms/step
# Epoch 37/50
# 63/63 - 42s - loss: 0.5530 - accuracy: 0.8216 - val_loss: 1.6610 - val_accuracy: 0.4423 - 42s/epoch - 665ms/step
# Epoch 38/50
# 63/63 - 42s - loss: 0.4521 - accuracy: 0.8437 - val_loss: 1.8389 - val_accuracy: 0.4038 - 42s/epoch - 664ms/step
# Epoch 39/50
# 63/63 - 42s - loss: 0.4766 - accuracy: 0.8257 - val_loss: 1.5748 - val_accuracy: 0.3846 - 42s/epoch - 662ms/step
# Epoch 40/50
# 63/63 - 41s - loss: 0.4681 - accuracy: 0.8397 - val_loss: 1.6578 - val_accuracy: 0.5577 - 41s/epoch - 648ms/step
# Epoch 41/50
# 63/63 - 42s - loss: 0.4711 - accuracy: 0.8297 - val_loss: 1.5665 - val_accuracy: 0.5385 - 42s/epoch - 669ms/step
# Epoch 42/50
# 63/63 - 42s - loss: 0.5915 - accuracy: 0.7876 - val_loss: 1.2379 - val_accuracy: 0.4615 - 42s/epoch - 663ms/step
# Epoch 43/50
# 63/63 - 42s - loss: 0.5596 - accuracy: 0.8076 - val_loss: 1.5831 - val_accuracy: 0.5000 - 42s/epoch - 667ms/step
# Epoch 44/50
# 63/63 - 43s - loss: 0.4613 - accuracy: 0.8277 - val_loss: 1.5261 - val_accuracy: 0.5192 - 43s/epoch - 675ms/step
# Epoch 45/50
# 63/63 - 41s - loss: 0.4201 - accuracy: 0.8457 - val_loss: 1.8986 - val_accuracy: 0.5192 - 41s/epoch - 651ms/step
# Epoch 46/50
# 63/63 - 42s - loss: 0.4164 - accuracy: 0.8597 - val_loss: 1.5894 - val_accuracy: 0.4038 - 42s/epoch - 668ms/step
# Epoch 47/50
# 63/63 - 42s - loss: 0.3812 - accuracy: 0.8577 - val_loss: 1.9110 - val_accuracy: 0.3846 - 42s/epoch - 661ms/step
# Epoch 48/50
# 63/63 - 41s - loss: 0.3703 - accuracy: 0.8577 - val_loss: 1.6333 - val_accuracy: 0.4423 - 41s/epoch - 649ms/step
# Epoch 49/50
# 63/63 - 42s - loss: 0.3563 - accuracy: 0.8637 - val_loss: 2.0560 - val_accuracy: 0.4615 - 42s/epoch - 663ms/step
# Epoch 50/50
# 63/63 - 41s - loss: 0.3231 - accuracy: 0.8717 - val_loss: 1.6236 - val_accuracy: 0.4808 - 41s/epoch - 648ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
